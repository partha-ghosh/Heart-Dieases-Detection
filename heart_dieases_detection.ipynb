# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

import copy

# %%
data = pd.read_csv('processed.cleveland.data', 
                   names=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
                  )
data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
data.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# num           int64
# dtype: object

# %%
np.sum(data == '?')
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
data = data.replace('?', np.nan)

# %%
data.fillna(data.median())
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# 1      2.0  3.0  3.0    2
# 2      2.0  2.0  7.0    1
# 3      3.0  0.0  3.0    0
# 4      1.0  0.0  3.0    0
# ..     ...  ...  ...  ...
# 298    2.0  0.0  7.0    1
# 299    2.0  2.0  7.0    2
# 300    2.0  1.0  7.0    3
# 301    2.0  1.0  3.0    1
# 302    1.0    0  3.0    0
#
# [303 rows x 14 columns]

# %%
# NAN_rows_indices = list(np.where(data == '?')[0])
# NAN_rows = data.iloc[NAN_rows_indices]
# data = data.drop(NAN_rows_indices)

# %%
data['ca'] = pd.to_numeric(data['ca'])
data['thal'] = pd.to_numeric(data['thal'])

# %%
def one_hot_categories(data, categories):
    for category in categories:
        one_hot = pd.get_dummies(data[category], prefix=category)
        data = data.drop(category, axis=1)
        data = data.join(one_hot)
    return data

# %%
data = one_hot_categories(data, ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal'])

# %%
data['num'][data['num'] > 0] = 1
# Out:
# <ipython-input-11-f729322243a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['num'][data['num'] > 0] = 1

# %%
data = data.sample(frac=1)

# %%
data_test = data[:50]
data_train = data[50:]

y_test = data_test['num']
X_test = data_test.drop(columns=['num'])

y_train = data_train['num']
X_train = data_train.drop(columns=['num'])

X_train = np.array(X_train, dtype=np.float32)
y_train = np.array(y_train, dtype=np.float32)

X_test = np.array(X_test, dtype=np.float32)
y_test = np.array(y_test, dtype=np.float32)

X_train = torch.tensor(X_train)
y_train = torch.tensor(y_train)

X_test = torch.tensor(X_test)
y_test = torch.tensor(y_test)

# %%
# class DimReduction(nn.Module):
#     def __init__(self, down_layer_sizes, up_layer_sizes):
#         super().__init__()
#         self.down_layers = nn.ModuleList([])
#         self.up_layers = nn.ModuleList([])
        
#         for i in range(1, len(down_layer_sizes)):
#             self.down_layers.append(nn.Linear(down_layer_sizes[i-1], down_layer_sizes[i]))
            
#         for i in range(1, len(up_layer_sizes)):
#             self.up_layers.append(nn.Linear(up_layer_sizes[i-1], up_layer_sizes[i]))
        
#     def forward(self, x):
#         out = x
#         for i in range(len(self.down_layers)):
#             out = nn.functional.relu(self.down_layers[i](out))
        
#         for i in range(len(self.up_layers)-1):
#             out = nn.functional.relu(self.up_layers[i](out))
        
#         out = self.up_layers[-1](out)
#         return out
    
#     def reduce_dim(self, x):
#         out = x
        
#         for i in range(len(self.down_layers) - 1):
#             out = nn.functional.relu(self.down_layers[i](out))
            
#         out = self.down_layers[-1](out)
#         return out
    
# num_epochs = 2000
# batch_size = 16
# n_total_steps = len(X_train) // batch_size
# learning_rate = 0.001

# model = DimReduction([X_train.shape[1], 64, 32, 24], [24, 32, 64, X_train.shape[1]])
# loss_fn = nn.MSELoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# for epoch in range(num_epochs):
#     X_train = X_train[torch.randperm(X_train.size()[0])]
#     for step in range(n_total_steps):
#         input_ = X_train[step*batch_size : (step+1)*batch_size]
#         output = model(input_)
#         loss = loss_fn(output, input_)
        
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
        
#         if (epoch+1)%10 == 0:
#             print(f'epoch {epoch+1} / {num_epochs}, loss = {loss.item():.4f}', end='\r')
            
            
# with torch.no_grad():
#     X_train_reduced = model.reduce_dim(X_train)
#     X_test_reduced = model.reduce_dim(X_test)

# %%
class Classifier(nn.Module):
    def __init__(self, layer_sizes):
        super().__init__()
        self.linear_layers = nn.ModuleList([])
        for i in range(1, len(layer_sizes)):
            self.linear_layers.append(nn.Linear(layer_sizes[i-1], layer_sizes[i]))
        
    def forward(self, x):
        out = x
        for i in range(len(self.linear_layers)-1):
            out = nn.functional.relu(self.linear_layers[i](out))
        
        out = self.linear_layers[-1](out)
        out = torch.sigmoid(out)
        return out

# %%
num_epochs = 500
batch_size = 16
n_total_steps = len(X_train) // batch_size
learning_rate = 0.001

# %%
classifier = Classifier([X_train.shape[1], 16, 8, 4, 1])
loss_fn = nn.BCELoss()
optimizer = torch.optim.Adam(classifier.parameters(), lr=learning_rate)

# %%
train_losses = []
test_losses = []
test_accuracies = []
old_test_accuracy = 0
for epoch in range(num_epochs):
    train_loss = 0
    for step in range(n_total_steps):
        input_ = X_train[step*batch_size : (step+1)*batch_size]
        output = classifier(input_)
        loss = loss_fn(output.flatten(), y_train[step*batch_size : (step+1)*batch_size])
        train_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    train_loss = train_loss/n_total_steps
    train_losses.append(train_loss)
            
    with torch.no_grad():
        y_hat = classifier(X_test)
        test_loss = loss_fn(y_hat.flatten(), y_test)
        test_losses.append(test_loss)
        test_accuracy = torch.sum(np.round(y_hat.flatten()) == y_test).item() * 100/len(y_test)
        test_accuracies.append(test_accuracy)
        
    if (epoch + 1) % 10 == 0:
        print(f'epoch {epoch+1} / {num_epochs}, training loss = {train_loss:.4f}, test loss = {test_loss.item():.4f}, test accuracy = {test_accuracy:.4f}')
        
    if test_accuracy >= old_test_accuracy:
        old_test_accuracy = test_accuracy
        best_model_state_dict = copy.deepcopy(classifier.state_dict())
# Out:
# epoch 10 / 500, training loss = 0.6311, test loss = 0.6174, test accuracy = 60.0000
# epoch 20 / 500, training loss = 0.5917, test loss = 0.5849, test accuracy = 72.0000
# epoch 30 / 500, training loss = 0.5548, test loss = 0.5600, test accuracy = 74.0000
# epoch 40 / 500, training loss = 0.5194, test loss = 0.5285, test accuracy = 80.0000
# epoch 50 / 500, training loss = 0.4786, test loss = 0.4914, test accuracy = 88.0000
# epoch 60 / 500, training loss = 0.4535, test loss = 0.4808, test accuracy = 84.0000
# epoch 70 / 500, training loss = 0.4297, test loss = 0.4745, test accuracy = 84.0000
# epoch 80 / 500, training loss = 0.4046, test loss = 0.4648, test accuracy = 86.0000
# epoch 90 / 500, training loss = 0.3918, test loss = 0.4628, test accuracy = 84.0000
# epoch 100 / 500, training loss = 0.3856, test loss = 0.4646, test accuracy = 84.0000
# epoch 110 / 500, training loss = 0.3684, test loss = 0.4609, test accuracy = 84.0000
# epoch 120 / 500, training loss = 0.3586, test loss = 0.4673, test accuracy = 84.0000
# epoch 130 / 500, training loss = 0.3509, test loss = 0.4647, test accuracy = 84.0000
# epoch 140 / 500, training loss = 0.3416, test loss = 0.4783, test accuracy = 84.0000
# epoch 150 / 500, training loss = 0.3391, test loss = 0.4733, test accuracy = 84.0000
# epoch 160 / 500, training loss = 0.3300, test loss = 0.4801, test accuracy = 86.0000
# epoch 170 / 500, training loss = 0.3215, test loss = 0.4855, test accuracy = 86.0000
# epoch 180 / 500, training loss = 0.3181, test loss = 0.4840, test accuracy = 86.0000
# epoch 190 / 500, training loss = 0.3086, test loss = 0.4795, test accuracy = 84.0000
# epoch 200 / 500, training loss = 0.3009, test loss = 0.4800, test accuracy = 84.0000
# epoch 210 / 500, training loss = 0.2959, test loss = 0.4724, test accuracy = 82.0000
# epoch 220 / 500, training loss = 0.2903, test loss = 0.4779, test accuracy = 86.0000
# epoch 230 / 500, training loss = 0.2804, test loss = 0.4902, test accuracy = 84.0000
# epoch 240 / 500, training loss = 0.2771, test loss = 0.5017, test accuracy = 82.0000
# epoch 250 / 500, training loss = 0.2718, test loss = 0.4925, test accuracy = 84.0000
# epoch 260 / 500, training loss = 0.2634, test loss = 0.5065, test accuracy = 82.0000
# epoch 270 / 500, training loss = 0.2593, test loss = 0.5122, test accuracy = 82.0000
# epoch 280 / 500, training loss = 0.2567, test loss = 0.5095, test accuracy = 82.0000
# epoch 290 / 500, training loss = 0.2516, test loss = 0.5242, test accuracy = 82.0000
# epoch 300 / 500, training loss = 0.2434, test loss = 0.5289, test accuracy = 82.0000
# epoch 310 / 500, training loss = 0.2377, test loss = 0.5338, test accuracy = 84.0000
# epoch 320 / 500, training loss = 0.2363, test loss = 0.5362, test accuracy = 84.0000
# epoch 330 / 500, training loss = 0.2286, test loss = 0.5419, test accuracy = 82.0000
# epoch 340 / 500, training loss = 0.2261, test loss = 0.5619, test accuracy = 80.0000
# epoch 350 / 500, training loss = 0.2241, test loss = 0.5427, test accuracy = 82.0000
# epoch 360 / 500, training loss = 0.2177, test loss = 0.5325, test accuracy = 82.0000
# epoch 370 / 500, training loss = 0.2103, test loss = 0.5822, test accuracy = 82.0000
# epoch 380 / 500, training loss = 0.2065, test loss = 0.5893, test accuracy = 82.0000
# epoch 390 / 500, training loss = 0.2012, test loss = 0.5979, test accuracy = 82.0000
# epoch 400 / 500, training loss = 0.1960, test loss = 0.6019, test accuracy = 82.0000
# epoch 410 / 500, training loss = 0.1970, test loss = 0.6131, test accuracy = 82.0000
# epoch 420 / 500, training loss = 0.1929, test loss = 0.6065, test accuracy = 82.0000
# epoch 430 / 500, training loss = 0.1919, test loss = 0.6072, test accuracy = 80.0000
# epoch 440 / 500, training loss = 0.2008, test loss = 0.6244, test accuracy = 78.0000
# epoch 450 / 500, training loss = 0.2013, test loss = 0.6398, test accuracy = 84.0000
# epoch 460 / 500, training loss = 0.1844, test loss = 0.6229, test accuracy = 84.0000
# epoch 470 / 500, training loss = 0.1841, test loss = 0.6472, test accuracy = 82.0000
# epoch 480 / 500, training loss = 0.1666, test loss = 0.6453, test accuracy = 80.0000
# epoch 490 / 500, training loss = 0.1680, test loss = 0.6615, test accuracy = 80.0000
# epoch 500 / 500, training loss = 0.1552, test loss = 0.6806, test accuracy = 80.0000

# %%
plt.plot(train_losses, label="training loss")
plt.plot(test_losses, label="test loss")
plt.legend()
plt.show()

# %%
plt.plot(test_accuracies)
plt.show()

# %%
best_model = Classifier([X_test.shape[1], 16, 8, 4, 1])
best_model.load_state_dict(best_model_state_dict)
with torch.no_grad():
    y_hat = best_model(X_test)
    
print(f"Best Model Accuracy: {torch.sum(np.round(y_hat.flatten()) == y_test).item() * 100 / len(y_test)}%")
# Out:
# Best Model Accuracy: 88.0%
